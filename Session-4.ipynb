# %% [markdown]
# # SESSION 4 - StringsTopics:String methods: upper, lower, replace, splitindexing & slicingFormatting stringsDemo:Clean product names like &quot; samsung-Mobile
# &quot;

# %% [markdown]
# TASKS

# %% [markdown]
# 1. Take the string 'Flipkart-Sale2024' and use string methods to convert it to lowercase, replace the dash with a space, and print the result.

# %%
sale = "Flipkart-Sale2024"

sale = sale.lower()
sale = sale.replace("-" , " ")
print(sale)
# Out:
# flipkart sale2024

# %% [markdown]
# 2. Given the product name ' OnePlus Nord-CE 3 ', write code to clean it by removing extra spaces, converting all letters to uppercase, and replacing the dash with a colon .< br><br><em><strong>Hint :< /strong> Use
# strip0, upper(), and replace() methods in sequence .< /em>

# %%
namee = "OnePlus Nord-CE 3"

namee = namee.strip()
print(namee)
namee = namee.replace(" " , "")
print(namee)
namee = namee.replace("-" , ":")
print(namee)
namee = namee.upper()
print(namee)

namee = namee.strip().replace(" ", "").replace("-", ":").upper()
print(namee)
# Out:
# OnePlus Nord-CE 3
# OnePlusNord-CE3
# OnePlusNord:CE3
# ONEPLUSNORD:CE3
# ONEPLUSNORD:CE3

# %% [markdown]
# 3. Write a function split_product_code(product_code) that takes a string like 'ZOMATO-FOOD-2024' and returns a list of its parts using the split( method.

# %%
def split_product_code(product_code):
    return product_code.split("-")

newww = split_product_code("ZOMAto-FOOD-2024")
print(newww)
# Out:
# ['ZOMAto', 'FOOD', '2024']

# %% [markdown]
# 4. Given the string 'Spotify_Premium_Offer', use string slicing to extract and print only the word 'Premium'.

# %%
givene = "Spotify_primum_offer"

print(givene[8:14])
# Out:
# primum

# %% [markdown]
# 5. Format and print a message using variables: product = 'Myntra Shirt', price = 799.5. The output should be: 'Deal: Myntra Shirt is available at ₹799.50 only!' using string formatting.

# %%
product = "Myntra Shirt"
price = 799.5

print(f"Deal : {product} is available at ${price} only!!")
# Out:
# Deal : Myntra Shirt is available at $799.5 only!!
