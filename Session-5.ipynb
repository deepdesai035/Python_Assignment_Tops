# %% [markdown]
# # SESSION 5 - Lists & TuplesTopics:List operations: append, extend, popTuple immutabilityWhen to use lists vs tuplesDemo:Create a list of customer IDs, update and
# iterate
#
# TASKS

# %% [markdown]
# 1. Create a list called playlist_ids with 5 song IDs (as integers) that you might see in a Spotify playlist, and print the list.

# %%
playlist_ids = [12,31,1,2,14,2,9]
print(playlist_ids)
# Out:
# [12, 31, 1, 2, 14, 2, 9]

# %% [markdown]
# 2. Add two more song IDs to your playlist_ids list using both append() and extend(, then print the updated list .< br><br><em><strong>Hint :< /strong> Use append0 for a single ID and extend() for adding multiple IDs
# at once .< /em>

# %%
play = [8,7,6,5,4,3]
playlist_ids.extend(play)
print(playlist_ids)
playlist_ids.append(1111)
print(playlist_ids)
# Out:
# [12, 31, 1, 2, 14, 2, 9, 8, 7, 6, 5, 4, 3, 8, 7, 6, 5, 4, 3, 1111, 8, 7, 6, 5, 4, 3, 1111, 8, 7, 6, 5, 4, 3, 1111, 8, 7, 6, 5, 4, 3, 1111, 8, 7, 6, 5, 4, 3, 1111, 8, 7, 6, 5, 4, 3, 1111, 8, 7, 6, 5, 4, 3, 1111, 8, 7, 6, 5, 4, 3, 1111, 8, 7, 6, 5, 4, 3, 1111, 8, 7, 6, 5, 4, 3]
# [12, 31, 1, 2, 14, 2, 9, 8, 7, 6, 5, 4, 3, 8, 7, 6, 5, 4, 3, 1111, 8, 7, 6, 5, 4, 3, 1111, 8, 7, 6, 5, 4, 3, 1111, 8, 7, 6, 5, 4, 3, 1111, 8, 7, 6, 5, 4, 3, 1111, 8, 7, 6, 5, 4, 3, 1111, 8, 7, 6, 5, 4, 3, 1111, 8, 7, 6, 5, 4, 3, 1111, 8, 7, 6, 5, 4, 3, 1111, 8, 7, 6, 5, 4, 3, 1111]

# %% [markdown]
# 3. Simulate removing the last played song from your playlist_ids list using pop0, and display the removed ID along with the remaining playlist.

# %%
lastsong = playlist_ids.pop()

# %% [markdown]
# 4. Create a tuple called insta_filters with 4 Instagram filter names (as strings). Try to change the first filter name and observe what error you get .< br><br><em><strong>Hint :< /strong> Tuples are immutable. Note down
# the error message .< /em>

# %%
filters = ("room" , "cozy" , "fresh" ,"energetic")

filters[0] = "romcom"

#TypeError: 'tuple' object does not support item assignment
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 filters = ("room" , "cozy" , "fresh" ,"energetic")
# ----> 3 filters[0] = "romcom"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# 5. Write a short Python script that takes a scenario (like a list of recent Zomato orders vs a tuple of fixed IPL team names) and prints which one should use a list and which should use a tuple, explaining your choice in a
# comment.

# %%
keyy = int(input("What you want to enter first zomato order(press 0 for zomato) or Ipl scores(press 1 for ipl) "))

if keyy == 0:
    print("Enter the orders when stop press 0")
    count = 1 
    list1 = []
    while count != "0":
        count = input("Enter the order name :- ")
        list1.append(count)
    print(list1)
    
elif keyy ==1:
    print("enter the ipl scores and type 'n' when to stop ")
    count = 1 
    tuple1 = []
    while count != "n":
        count = input("enter the ipl score :- ")
        if count != "n":
            tuple1.append(int(count))
    tuple1 = tuple(tuple1)
    print(tuple1)
else:
    print("enter the correct number to proceed")
print(list1 , tuple1)
# Out:
# enter the correct number to proceed
# ['deep', 'raita', 'faluda', 'burger', 'naan', 'moito', 'halwa', 'basundi', '0'] (12, 213, 213, 43, 123, 12, 55, 56)

# %% [markdown]
# ## as you can see i need to create a list first and then add the ipl score and at last converted to tiple as tuple are immutable
