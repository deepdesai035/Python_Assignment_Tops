# %% [markdown]
# # SESSION 2 - Python Syntax, Keywords, Variables & CommentsTopics:Indentation rulesNaming conventionsComments (# and multiline)Variables: dynamic
# typingDemo:Create variables for sales, region, discount

# %% [markdown]
# TASKS

# %% [markdown]
# 1. Create three variables in Python named item_price, delivery_fee, and coupon_discount, and assign them values representing a Swiggy order (e.g., 250, 30, 20). Print each variable.

# %%
item_price = 250 
delivery_fee = 30 
coupon_discount = 20

print(item_price)
print(delivery_fee)
print(coupon_discount)
# Out:
# 250
# 30
# 20

# %% [markdown]
# 2. Write a Python script that uses indentation correctly to check if a Flipkart product's price is above 1000; if yes, print 'Eligible for free delivery', else print 'Delivery charges apply' .< br><br><em><strong>Hint :< /strong>
# Use an if-else block and make sure your indentation is consistent .< /em>

# %%
flipkart_product = int(input("enter the product value"))

if flipkart_product > 1000:
    print("Eligible for free delivery")
else:
    print("delivery charges will apply")
# Out:
# Eligible for free delivery

# %% [markdown]
# 3. Add both single-line and multi-line comments in your script explaining what each section does, using # for single-line and triple quotes for multi-line comments.

# %%
# single line comment

''' this is a muiltiple line comment 

this is a second line 

this is a third line '''
# Out:
# ' this is a muiltiple line comment \n\nthis is a second line \n\nthis is a third line '

# %% [markdown]
# 4. Create variables for an IPL match: team_name, runs_scored, and overs_played. Assign appropriate values and print them using the correct naming conventions for Python variables .< br><br><em><strong>Constraint:
# </strong> Use snake_case for all variable names .< /em>

# %%
team_name = "deep"
runs_scored = 200
overs_played = 20

print(f"team name is {team_name}")
print(f"runs scored {runs_scored}")
print(f"overs played {overs_played}")
# Out:
# team name is deep
# runs scored 200
# overs played 20
