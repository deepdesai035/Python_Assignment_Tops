# %% [markdown]
# # SESSION 3 - Data Types in PythonTopics:int, float, str, booltype() functionType castingDemo:Convert numeric strings to floats for analysis
#
# TASKS

# %% [markdown]
# 1. Declare four variables in Python: your age as an int, your height in centimeters as a float, your name as a str, and whether you have a Spotify account as a bool. Print each variable and use the type() function to display
# its data type.

# %%
age = 25
height = 165.5
name = "Deep"
spotify = True

print(f" the age varibale value is {age} and type is :- {type(age)}")
print(f" the height varibale value is {height} and type is :- {type(height)}")
print(f" the name varibale value is {name} and type is :- {type(name)}")
print(f" the spotify varibale value is {spotify} and type is :- {type(spotify)}")
# Out:
#  the age varibale value is 25 and type is :- <class 'int'>
#  the height varibale value is 165.5 and type is :- <class 'float'>
#  the name varibale value is Deep and type is :- <class 'str'>
#  the spotify varibale value is True and type is :- <class 'bool'>

# %% [markdown]
# 2. Write a function total_cart_amount(prices) that takes a list of product prices as strings (like ['199.99', '49', '350.75']) and returns the total as a float. Print the result for a sample Flipkart-style cart .< br><br><em>
# <strong>Hint :< /strong> Use float() to convert each string before summing .< /em>

# %%
def total_cart_amount(prices):
    return print(f"the sum is {sum(prices)}")

price = []
price.append(float(input("enter the price in float :- ")))
price.append(float(input("enter the price in float :- ")))
price.append(float(input("enter the price in float :- ")))

print(price)
total_cart_amount(price)
# Out:
# [121239.237, 213236.2321, 21361.8732]
# the sum is 355837.3423

# %% [markdown]
# 3. Create a script that asks the user to input their cricket score as a string, converts it to an int, and prints 'Half-century!' if the score is 50 or more, otherwise prints 'Keep going!' .< br><br><em><strong>Constraint:
# </strong> Use input(), int(), and if-else .< /em>

# %%
score = int(input("enter the your score:- "))

if score >= 50:
    print("half century")
else:
    print("keep going")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 score = int(input("enter the your score:- "))
#       3 if score >= 50:
#       4     print("half century")
#
# File f:\anaconda\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File f:\anaconda\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %% [markdown]
# 4. Given the variable is_premium = 'True' (as a string), write code to correctly convert it to a boolean value and print its type .< br><br><em><strong>Hint :< /strong> The bool() function alone won't work as expected.
# Think about string comparison .< /em>

# %%
is_premium = "True"

if is_premium == "True":
    is_premium = True

print(type(is_premium))
# Out:
# <class 'bool'>
