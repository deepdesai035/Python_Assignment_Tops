# %% [markdown]
# SESSION 6 - Dictionaries & SetsTopics:Key-value pairsAdding, updating, deletingSet operations (union, intersection)Demo:Create product ? price dictionary

# %% [markdown]
# TASKS

# %% [markdown]
# 1. Create a Python dictionary called insta_followers that stores the number of followers for 5 Instagram influencers (use their usernames as keys and follower counts as values). Print the dictionary.

# %%
instagram = {
    "deep" : 1200,
    "noor" : 100,
    "hamza" :120,
    "soolii" :100

}

instagram
# Out:
# {'deep': 1200, 'noor': 100, 'hamza': 120, 'soolii': 100}

# %% [markdown]
# 2. Add a new influencer to your insta_followers dictionary and update the follower count for one existing influencer. Then, delete one influencer from the dictionary and print the updated dictionary.

# %%
instagram["ruksar"] = 1200
instagram["soolii"] = 100
del instagram["soolii"]

instagram
# Out:
# {'deep': 1200, 'noor': 100, 'hamza': 120, 'ruksar': 1200}

# %% [markdown]
# 3. Given a dictionary called food_prices with 5 Zomato food items as keys and their prices as values, write code to display all items that cost more than ₹200.

# %%
food_prices = {
    "tootthpaste": 120,
    "brush" : 20,
    "chicken":1200,
    "iphone": 80000
}

for key in food_prices:
    if food_prices[key] >100:
        print(key)
# Out:
# tootthpaste
# chicken
# iphone

# %% [markdown]
# 4. Create two sets: flipkart_users and myntra_users, each containing 5 unique usernames. Find and print the set of users who have accounts on both platforms using set intersection.

# %%
flipkart_users = {"deep", "desai" , "darshan", "bhavna","maya"}
myntra_users = {"deep" , "yuvraj", "akansha", "dhruv", "mina"}

print("coo=mmon user of the both platform are : - ", flipkart_users.intersection(myntra_users))
# Out:
# coo=mmon user of the both platform are : -  {'deep'}

# %% [markdown]
# 5. Write a function get_unique_artists(spotify_playlist1, spotify_playlist2) that takes two sets of artist names and returns a set of all unique artists across both playlists (set union) .< br><br><em><strong>Hint :< /strong>
# Use the union() method or the | operator for sets .< /em>

# %%
flipkart_users = {"deep", "desai" , "darshan", "bhavna","maya"}
myntra_users = {"deep" , "yuvraj", "akansha", "dhruv", "mina"}

both = flipkart_users.union(myntra_users)
both
# Out:
# {'akansha',
#  'bhavna',
#  'darshan',
#  'deep',
#  'desai',
#  'dhruv',
#  'maya',
#  'mina',
#  'yuvraj'}
